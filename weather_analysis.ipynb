# %%
pip install meteostat pandas

# %%
from datetime import datetime
import meteostat as mt
import pandas as pd
from meteostat import Point

# %%
start = datetime(1990, 1, 1)
end = datetime(2025, 8, 24)

# %%
Kowloon = Point(22.3167, 114.1833, 92)

# %%
location_id = '45007'  # Replace XYZ123 with the desired weather station ID

# %%
data = mt.Monthly(location_id, start, end)
data = data.fetch()

# %%
df = pd.DataFrame(data)

# %%
print(df.head())
# Out:
#             tavg  tmin  tmax  prcp  wspd  pres  tsun
# time
# 1990-01-01  16.5  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 1990-02-01  16.7  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 1990-03-01  18.9  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 1990-04-01  21.8  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>
# 1990-05-01  25.0  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='time', y='tavg')  # Adjust columns as needed
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 420 entries, 1990-01-01 to 2025-07-01
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tavg    420 non-null    Float64
#  1   tmin    239 non-null    Float64
#  2   tmax    239 non-null    Float64
#  3   prcp    33 non-null     Float64
#  4   wspd    0 non-null      Float64
#  5   pres    82 non-null     Float64
#  6   tsun    0 non-null      Float64
# dtypes: Float64(7)
# memory usage: 45.3 KB

# %%
def dfs_concat(input) :
    dfs = df.loc['1990'+'-06-01':'1990'+'-08-31']
    for y in range(1991,2026) :
        dfs = pd.concat([dfs,df.loc[str(y)+'-06-01':str(y)+'-08-31']])
    return dfs

def dfa_concat(input) :
    dfa = df.loc['1990'+'-09-01':'1990'+'-11-30']
    for y in range(1991,2026) :
        dfa = pd.concat([dfs,df.loc[str(y)+'-09-01':str(y)+'-11-30']])
    return dfa

def dfw_concat(input) :
    dfw = df.loc['1990'+'-12-01':'1990'+'-02-28']
    for y in range(1991,2026) :
        dfw = pd.concat([dfs,df.loc[str(y)+'-12-01':str(y)+'-02-28']])
    return dfw

def dfsp_concat(input) :
    dfsp = df.loc['1990'+'-03-01':'1990'+'-05-31']
    for y in range(1991,2026) :
        dfsp = pd.concat([dfs,df.loc[str(y)+'-03-01':str(y)+'-05-31']])
    return dfsp
    #dfs = pd.concat([df.loc['2023'+'-06-01':'2023'+'-08-31'],df.loc['2025'+'-06-01':'2025'+'-08-31']])
#df.loc['2023'+'-06-01':'2023'+'-08-31']

# %%
dfs = dfs_concat(df)
print(dfs)
# Out:
#             tavg  tmin  tmax   prcp  wspd    pres  tsun
# time
# 1990-06-01  28.3  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1990-07-01  29.5  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1990-08-01  30.1  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1991-06-01  28.7  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1991-07-01  29.4  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# ...          ...   ...   ...    ...   ...     ...   ...
# 2024-06-01  29.4  27.5  31.5  259.2  <NA>  1007.2  <NA>
# 2024-07-01  30.4  28.5  32.9  216.0  <NA>  1005.8  <NA>
# 2024-08-01  30.3  28.2  33.0   <NA>  <NA>  1006.4  <NA>
# 2025-06-01  29.3  27.4  31.7  260.7  <NA>  1006.4  <NA>
# 2025-07-01  30.1  28.0  32.7  341.0  <NA>  1001.2  <NA>
#
# [104 rows x 7 columns]

# %%
dfw_concat(df)
# Out:
#             tavg  tmin  tmax   prcp  wspd    pres  tsun
# time
# 1990-06-01  28.3  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1990-07-01  29.5  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1990-08-01  30.1  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1991-06-01  28.7  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1991-07-01  29.4  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# ...          ...   ...   ...    ...   ...     ...   ...
# 2024-06-01  29.4  27.5  31.5  259.2  <NA>  1007.2  <NA>
# 2024-07-01  30.4  28.5  32.9  216.0  <NA>  1005.8  <NA>
# 2024-08-01  30.3  28.2  33.0   <NA>  <NA>  1006.4  <NA>
# 2025-06-01  29.3  27.4  31.7  260.7  <NA>  1006.4  <NA>
# 2025-07-01  30.1  28.0  32.7  341.0  <NA>  1001.2  <NA>
#
# [104 rows x 7 columns]

# %%
dfa = dfa_concat(df)
dfa.head(180)
# Out:
#             tavg  tmin  tmax   prcp  wspd    pres  tsun
# time
# 1990-06-01  28.3  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1990-07-01  29.5  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1990-08-01  30.1  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1991-06-01  28.7  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# 1991-07-01  29.4  <NA>  <NA>   <NA>  <NA>    <NA>  <NA>
# ...          ...   ...   ...    ...   ...     ...   ...
# 2024-06-01  29.4  27.5  31.5  259.2  <NA>  1007.2  <NA>
# 2024-07-01  30.4  28.5  32.9  216.0  <NA>  1005.8  <NA>
# 2024-08-01  30.3  28.2  33.0   <NA>  <NA>  1006.4  <NA>
# 2025-06-01  29.3  27.4  31.7  260.7  <NA>  1006.4  <NA>
# 2025-07-01  30.1  28.0  32.7  341.0  <NA>  1001.2  <NA>
#
# [104 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(30, 6))
sns.lineplot(data=dfs, x='time', y='tavg')  # Adjust columns as needed
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.show()

# %%
dfs.plot(y=['tavg'], kind='line')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1638779078.py in <cell line: 0>()
# ----> 1 dfs.plot(dfs.index,y=['tavg'], kind='line')
#       2 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     993                 if is_integer(x) and not data.columns._holds_integer():
#     994                     x = data_cols[x]
# --> 995                 elif not isinstance(data[x], ABCSeries):
#     996                     raise ValueError("x must be a label or position")
#     997                 data = data.set_index(x)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
# ...
